# %%
def even_or_odd(num):
    """Function to find Even and Odd number"""
    if num%2==0:
        print("The Number is Even")
    else:
        print("The number is Odd")

# %%
even_or_odd(43)
# Out:
# The number is Odd
